# %% [markdown]
# # Clone the repository and install dependencies

# %%
# Clone the main repo
# %%capture
! git clone https://github.com/shubham-goel/4D-Humans.git 4D-Humans
# %cd 4D-Humans

# %%
# !pip install torch
# !pip install -e .[all]
# !wget https://github.com/classner/up/raw/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# !mkdir data/
# !mv basicModel_neutral_lbs_10_207_0_v1.0.0.pkl data/
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Obtaining file:///content/4D-Humans
#   Preparing metadata (setup.py) ... done
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2 (from hmr2==0.0.0)
#   Cloning https://github.com/facebookresearch/detectron2 to /tmp/pip-install-fp2969t6/detectron2_ec4501f6ecc347aeb533907c6da4a488
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2 /tmp/pip-install-fp2969t6/detectron2_ec4501f6ecc347aeb533907c6da4a488
#   Resolved https://github.com/facebookresearch/detectron2 to commit 017abbfa5f2c2a2afa045200c2af9ccf2fc6227f
#   Preparing metadata (setup.py) ... done
# Collecting numpy==1.23.0 (from hmr2==0.0.0)
#   Downloading numpy-1.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 86.1 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.16.0+cu118)
# Collecting pytorch-lightning (from hmr2==0.0.0)
#   Downloading pytorch_lightning-2.1.2-py3-none-any.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.9/776.9 kB 69.8 MB/s eta 0:00:00
# Collecting smplx==0.1.28 (from hmr2==0.0.0)
#   Downloading smplx-0.1.28-py3-none-any.whl (29 kB)
# Collecting pyrender (from hmr2==0.0.0)
#   Downloading pyrender-0.1.45-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 88.1 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (4.8.0.76)
# Collecting yacs (from hmr2==0.0.0)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (0.19.3)
# Collecting einops (from hmr2==0.0.0)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.0 MB/s eta 0:00:00
# Collecting timm (from hmr2==0.0.0)
#   Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 101.1 MB/s eta 0:00:00
# Collecting webdataset (from hmr2==0.0.0)
#   Downloading webdataset-0.2.79-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 10.2 MB/s eta 0:00:00
# Collecting dill (from hmr2==0.0.0)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.6 MB/s eta 0:00:00
# Collecting chumpy (from hmr2==0.0.0)
#   Downloading chumpy-0.70.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from hmr2==0.0.0) (1.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->hmr2==0.0.0) (2.1.0)
# Requirement already satisfied: scipy>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from chumpy->hmr2==0.0.0) (1.11.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from chumpy->hmr2==0.0.0) (1.16.0)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.14.1)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.0 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 21.6 MB/s eta 0:00:00
# Collecting black (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading black-23.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 34.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (23.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from yacs->hmr2==0.0.0) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hmr2==0.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->hmr2==0.0.0) (2023.3.post1)
# Collecting freetype-py (from pyrender->hmr2==0.0.0)
#   Downloading freetype_py-2.4.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from pyrender->hmr2==0.0.0) (2.31.6)
# Collecting pyglet>=1.4.10 (from pyrender->hmr2==0.0.0)
#   Downloading pyglet-2.0.10-py3-none-any.whl (858 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 858.3/858.3 kB 33.1 MB/s eta 0:00:00
# Collecting PyOpenGL==3.1.0 (from pyrender->hmr2==0.0.0)
#   Downloading PyOpenGL-3.1.0.zip (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting trimesh (from pyrender->hmr2==0.0.0)
#   Downloading trimesh-4.0.5-py3-none-any.whl (688 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.5/688.5 kB 55.9 MB/s eta 0:00:00
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning->hmr2==0.0.0)
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 66.2 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.8.0 (from pytorch-lightning->hmr2==0.0.0)
#   Downloading lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->hmr2==0.0.0) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->hmr2==0.0.0) (1.4.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm->hmr2==0.0.0) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->hmr2==0.0.0) (0.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->hmr2==0.0.0) (2.31.0)
# Collecting braceexpand (from webdataset->hmr2==0.0.0)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec->torch->hmr2==0.0.0) (3.8.6)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 19.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning->hmr2==0.0.0) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.1.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->hmr2==0.0.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->hmr2==0.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->hmr2==0.0.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->hmr2==0.0.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->hmr2==0.0.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->hmr2==0.0.0) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch->hmr2==0.0.0) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch->hmr2==0.0.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch->hmr2==0.0.0) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch->hmr2==0.0.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch->hmr2==0.0.0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch->hmr2==0.0.0) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.2.2)
# Building wheels for collected packages: chumpy, detectron2, PyOpenGL, fvcore, antlr4-python3-runtime
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.70-py3-none-any.whl size=58264 sha256=d8e741299e4097ac4ca53b4de2ac55d7c8435c28eb3dbdc97ff8e5a50a80f6ff
#   Stored in directory: /root/.cache/pip/wheels/e0/c1/ef/29ba7be03653a29ef6f2c3e1956d6c4d8877f2b243af411db1
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6118749 sha256=a3225200dccdcb5646ed74760886561f0e87466f3b49d5a72f8bde5968579c69
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ea_vg75l/wheels/72/12/4e/46c698a8eae62144537235597979a91e2704df2b12301807c6
#   Building wheel for PyOpenGL (setup.py) ... done
#   Created wheel for PyOpenGL: filename=PyOpenGL-3.1.0-py3-none-any.whl size=1745192 sha256=034607eb78b0ebc1c45f4eae989926595a0cff6717c9bb843ee2bf459a509763
#   Stored in directory: /root/.cache/pip/wheels/a1/3c/d2/1f9533f908d86176637521e533c6cdb2d4e48b59003b5c3f19
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=9e92e811022b32205d8b3976818391e84ff3347b998e88368931fa9097867f83
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=43e643dea300ae7361d00bbe2a7e5e3dc4434634196d406c5921023a0fdd9c86
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built chumpy detectron2 PyOpenGL fvcore antlr4-python3-runtime
# Installing collected packages: PyOpenGL, pyglet, braceexpand, antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, numpy, mypy-extensions, lightning-utilities, freetype-py, einops, dill, webdataset, trimesh, iopath, hydra-core, black, torchmetrics, smplx, pyrender, fvcore, chumpy, timm, pytorch-lightning, hmr2, detectron2
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.7
#     Uninstalling PyOpenGL-3.1.7:
#       Successfully uninstalled PyOpenGL-3.1.7
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Running setup.py develop for hmr2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# tensorflow 2.14.0 requires numpy>=1.23.5, but you have numpy 1.23.0 which is incompatible.
# Successfully installed PyOpenGL-3.1.0 antlr4-python3-runtime-4.9.3 black-23.11.0 braceexpand-0.1.7 chumpy-0.70 detectron2-0.6 dill-0.3.7 einops-0.7.0 freetype-py-2.4.0 fvcore-0.1.5.post20221221 hmr2-0.0.0 hydra-core-1.3.2 iopath-0.1.9 lightning-utilities-0.10.0 mypy-extensions-1.0.0 numpy-1.23.0 omegaconf-2.3.0 pathspec-0.11.2 portalocker-2.8.2 pyglet-2.0.10 pyrender-0.1.45 pytorch-lightning-2.1.2 smplx-0.1.28 timm-0.9.12 torchmetrics-1.2.0 trimesh-4.0.5 webdataset-0.2.79 yacs-0.1.8
# --2023-11-30 19:49:27--  https://github.com/classner/up/raw/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl [following]
# --2023-11-30 19:49:27--  https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39001280 (37M) [application/octet-stream]
# Saving to: ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’
#
# basicModel_neutral_ 100%[===================>]  37.19M   208MB/s    in 0.2s
#
# 2023-11-30 19:49:28 (208 MB/s) - ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’ saved [39001280/39001280]

# %% [markdown]
# # Run the demo

# %%
# run hmr2 on a folder of images
# !python demo.py \
--img_folder example_data/images \
--out_folder demo_out \
--batch_size=48 --side_view --save_mesh
# Out:
# Downloading file: hmr2_data.tar.gz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/4dhumans/hmr2_data.tar.gz to /root/.cache/4DHumans/hmr2_data.tar.gz
#   [============================================================] 100.0% of 2585.0MB file
# Extracting file: hmr2_data.tar.gz
# data/
# data/smpl/
# data/smpl_mean_params.npz
# data/SMPL_to_J19.pkl
# logs/
# logs/train/
# logs/train/multiruns/
# logs/train/multiruns/hmr2/
# logs/train/multiruns/hmr2/0/
# logs/train/multiruns/hmr2/0/checkpoints/
# logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt
# logs/train/multiruns/hmr2/0/model_config.yaml
# logs/train/multiruns/hmr2/0/dataset_config.yaml
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../root/.cache/4DHumans/logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt`
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# model_final_f05665.pkl: 2.77GB [00:14, 189MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# downsampling_factor=11.122095108032227
# (6890, 3) (3,)

# %% [markdown]
# ### Visualize the reconstructions

# %%
from IPython.display import Image, display
import os
# https://colab.research.google.com/drive/1Ex4gE5v1bPR3evfhtG7sDHxQGsWwNwby?usp=sharing
output_images = ["demo_out/" + i for i in os.listdir("demo_out/") if ".png" in i]
for img in output_images:
  display(Image(img))

# %% [markdown]
# # Video Demo

# %% [markdown]
# ### Install PHALP

# %%
# !pip install git+https://github.com/brjathu/PHALP.git
# Out:
# Collecting git+https://github.com/brjathu/PHALP.git
#   Cloning https://github.com/brjathu/PHALP.git to /tmp/pip-req-build-mm5cai8b
#   Running command git clone --filter=blob:none --quiet https://github.com/brjathu/PHALP.git /tmp/pip-req-build-mm5cai8b
#   Resolved https://github.com/brjathu/PHALP.git to commit f56f03eec28c1b544b82fba2e4ca8000c7fe0ac7
#   Preparing metadata (setup.py) ... done
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2.git (from phalp==0.1.3)
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-install-hk8danyn/detectron2_15c915b5840e4314b15880230cc50429
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-install-hk8danyn/detectron2_15c915b5840e4314b15880230cc50429
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 017abbfa5f2c2a2afa045200c2af9ccf2fc6227f
#   Preparing metadata (setup.py) ... done
# Collecting pytube@ git+https://github.com/pytube/pytube.git (from phalp==0.1.3)
#   Cloning https://github.com/pytube/pytube.git to /tmp/pip-install-hk8danyn/pytube_268e20c438ac42789b560146441866db
#   Running command git clone --filter=blob:none --quiet https://github.com/pytube/pytube.git /tmp/pip-install-hk8danyn/pytube_268e20c438ac42789b560146441866db
#   Resolved https://github.com/pytube/pytube.git to commit a32fff39058a6f7e5e59ecd06a7467b71197ce35
#   Preparing metadata (setup.py) ... done
# Collecting pyopengl@ git+https://github.com/mmatl/pyopengl.git (from phalp==0.1.3)
#   Cloning https://github.com/mmatl/pyopengl.git to /tmp/pip-install-hk8danyn/pyopengl_58e03e4b006f48798e649d49ccb16cb8
#   Running command git clone --filter=blob:none --quiet https://github.com/mmatl/pyopengl.git /tmp/pip-install-hk8danyn/pyopengl_58e03e4b006f48798e649d49ccb16cb8
#   Resolved https://github.com/mmatl/pyopengl.git to commit 76d1261adee2d3fd99b418e75b0416bb7d2865e6
#   Preparing metadata (setup.py) ... done
# Collecting neural-renderer-pytorch@ git+https://github.com/shubham-goel/NMR.git (from phalp==0.1.3)
#   Cloning https://github.com/shubham-goel/NMR.git to /tmp/pip-install-hk8danyn/neural-renderer-pytorch_a4d02bc66cfd452fac43abbae43834d6
#   Running command git clone --filter=blob:none --quiet https://github.com/shubham-goel/NMR.git /tmp/pip-install-hk8danyn/neural-renderer-pytorch_a4d02bc66cfd452fac43abbae43834d6
#   Resolved https://github.com/shubham-goel/NMR.git to commit e990b3c70f48d39231f607c79d76ce3db4bf7483
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (4.8.0.76)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.2.2)
# Requirement already satisfied: pyrender in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.1.45)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.3.7)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (13.7.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.7.0)
# Collecting scenedetect[opencv] (from phalp==0.1.3)
#   Downloading scenedetect-0.6.2-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.3.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.9.12)
# Collecting av (from phalp==0.1.3)
#   Downloading av-11.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 44.8 MB/s eta 0:00:00
# Requirement already satisfied: smplx==0.1.28 in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.1.28)
# Requirement already satisfied: chumpy in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.70)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.23.0)
# Requirement already satisfied: torch>=1.0.1.post2 in /usr/local/lib/python3.10/dist-packages (from smplx==0.1.28->phalp==0.1.3) (2.1.0+cu118)
# Requirement already satisfied: scipy>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from chumpy->phalp==0.1.3) (1.11.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from chumpy->phalp==0.1.3) (1.16.0)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.14.1)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.3.0)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (23.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (23.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core->phalp==0.1.3) (4.9.3)
# Requirement already satisfied: freetype-py in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (2.4.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (2.31.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (3.2.1)
# Requirement already satisfied: pyglet>=1.4.10 in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (2.0.10)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (4.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->phalp==0.1.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->phalp==0.1.3) (2.16.1)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from scenedetect[opencv]->phalp==0.1.3) (8.1.7)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from scenedetect[opencv]->phalp==0.1.3) (4.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->phalp==0.1.3) (3.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (0.4.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.8.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->phalp==0.1.3) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (2.1.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.11.2)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm->phalp==0.1.3) (2.31.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.2.2)
# Building wheels for collected packages: phalp, neural-renderer-pytorch, pytube
#   Building wheel for phalp (setup.py) ... done
#   Created wheel for phalp: filename=phalp-0.1.3-py3-none-any.whl size=68081 sha256=726fe63cc243125812ea8bbcd2b12d66870ec16c9cfcb2f8cbbe800f8d49281b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hyavf0rw/wheels/78/60/a5/1f2ed47d3c8adf5676ba2fda887b106153d50952536ea113a9
#   Building wheel for neural-renderer-pytorch (setup.py) ... done
#   Created wheel for neural-renderer-pytorch: filename=neural_renderer_pytorch-1.1.3-cp310-cp310-linux_x86_64.whl size=7895065 sha256=a7607cce9c3ab011c03c7e77ffba1b295e7b28837d3f4b408631aabe4c006f95
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hyavf0rw/wheels/9f/7a/86/2e98acdc9b54233377868f5cf10ab13383e28d4f1733cdd28f
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=57579 sha256=50f6f218b964b2c36d56b1c7073301af87f723b356ad40b4b069ef5d471abff7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hyavf0rw/wheels/5a/12/87/c8ebc234373bbbfaa9bd27af202f15d1016cfcac72952cc0ec
# Successfully built phalp neural-renderer-pytorch pytube
# Installing collected packages: neural-renderer-pytorch, scenedetect, pytube, av, phalp
# Successfully installed av-11.0.0 neural-renderer-pytorch-1.1.3 phalp-0.1.3 pytube-15.0.0 scenedetect-0.6.2

# %% [markdown]
# ### Track and visualize

# %%
# !python track.py video.source="example_data/videos/gymnasts.mp4" video.start_frame=10 video.end_frame=60
# Out:
# [11/30 19:56:14] INFO     No OpenGL_accelerate module loaded: No module      ]8;id=544783;file:///usr/local/lib/python3.10/dist-packages/OpenGL/acceleratesupport.py\acceleratesupport.py]8;;\:]8;id=299776;file:///usr/local/lib/python3.10/dist-packages/OpenGL/acceleratesupport.py#17\17]8;;\
#                           named 'OpenGL_accelerate'
# --2023-11-30 19:56:16--  https://github.com/classner/up/raw/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl [following]
# --2023-11-30 19:56:16--  https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39001280 (37M) [application/octet-stream]
# Saving to: ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’
#
# basicModel_neutral_ 100%[===================>]  37.19M   218MB/s    in 0.2s
#
# 2023-11-30 19:56:16 (218 MB/s) - ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’ saved [39001280/39001280]
#
# Downloading file: head_faces.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/head_faces.npy to /root/.cache/phalp/3D/head_faces.npy
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: mean_std.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/mean_std.npy to /root/.cache/phalp/3D/mean_std.npy
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: smpl_mean_params.npz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/smpl_mean_params.npz to /root/.cache/phalp/3D/smpl_mean_params.npz
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: SMPL_to_J19.pkl
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/SMPL_to_J19.pkl to /root/.cache/phalp/3D/SMPL_to_J19.pkl
#   [============================================================] 100.0% of 1.0MB file
# Downloading file: texture.npz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/texture.npz to /root/.cache/phalp/3D/texture.npz
#   [============================================================] 100.0% of 0.6MB file
# Downloading file: bmap_256.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/bmap_256.npy to /root/.cache/phalp/3D/bmap_256.npy
#   [============================================================] 100.0% of 1.5MB file
# Downloading file: fmap_256.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/fmap_256.npy to /root/.cache/phalp/3D/fmap_256.npy
#   [============================================================] 100.0% of 0.3MB file
# Downloading file: hmar_v2_weights.pth
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/weights/hmar_v2_weights.pth to /root/.cache/phalp/weights/hmar_v2_weights.pth
#   [============================================================] 100.0% of 166.5MB file
# Downloading file: pose_predictor.pth
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/weights/pose_predictor_40006.ckpt to /root/.cache/phalp/weights/pose_predictor.pth
#   [============================================================] 100.0% of 139.8MB file
# Downloading file: pose_predictor.yaml
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/weights/config_40006.yaml to /root/.cache/phalp/weights/pose_predictor.yaml
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: ava_labels.pkl
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/ava/ava_labels.pkl to /root/.cache/phalp/ava/ava_labels.pkl
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: ava_class_mapping.pkl
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/ava/ava_class_mappping.pkl to /root/.cache/phalp/ava/ava_class_mapping.pkl
#   [============================================================] 100.0% of 0.0MB file
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 162MB/s]
# [2023-11-30 19:56:48,958][pytorch_lightning.utilities.migration.utils][INFO] - Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../root/.cache/4DHumans/logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt`
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# [2023-11-30 19:56:57,076][phalp.trackers.PHALP][INFO] - Loading Predictor model...
# [2023-11-30 19:56:57,968][phalp.trackers.PHALP][INFO] - Loading Detection model...
# [2023-11-30 19:57:10,905][detectron2.checkpoint.detection_checkpoint][INFO] - [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/ViTDet/COCO/cascade_mask_rcnn_vitdet_h/f328730692/model_final_f05665.pkl ...
# [2023-11-30 19:57:25,591][detectron2.checkpoint.detection_checkpoint][INFO] - [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x/139653917/model_final_2d9806.pkl ...
# [2023-11-30 19:57:25,593][iopath.common.download][INFO] - Downloading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x/139653917/model_final_2d9806.pkl ...
# model_final_2d9806.pkl: 431MB [00:01, 242MB/s]
# [2023-11-30 19:57:27,377][iopath.common.download][INFO] - Successfully downloaded /root/.torch/iopath_cache/detectron2/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x/139653917/model_final_2d9806.pkl. 431414189 bytes.
# [2023-11-30 19:57:27,648][phalp.trackers.PHALP][INFO] - Setting up Visualizer...
# [2023-11-30 19:57:28,726][phalp.utils.io][INFO] - Number of frames: 339
# [2023-11-30 19:57:32,242][phalp.trackers.PHALP][INFO] - Setting up DeepSort...
# [2023-11-30 19:57:32,243][phalp.trackers.PHALP][INFO] - Saving tracks at : outputs//results/gymnasts
# Tracking : gymnasts   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% eta : 0:00:00  time elapsed : 0:03:18

# %%
# Display the reconstruction video
def show_local_mp4_video(file_name, width=640, height=480):
  import io
  import base64
  from IPython.display import HTML
  video_encoded = base64.b64encode(io.open(file_name, 'rb').read())
  return HTML(data='''<video width="{0}" height="{1}" alt="test" controls>
                      <source src="data:video/mp4;base64,{2}" type="video/mp4" />
                      </video>'''.format(width, height, video_encoded.decode('ascii')))

# !ffmpeg -y -hide_banner -loglevel error -i outputs/PHALP_gymnasts.mp4 outputs/PHALP_gymnasts_ffmpeg.mp4
show_local_mp4_video('outputs/PHALP_gymnasts_ffmpeg.mp4', width=960, height=540)
# Out:
# <video width="960" height="540" alt="test" controls>
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                       </video>
